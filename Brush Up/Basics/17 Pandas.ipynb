# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford","Maruti", "TATA"],
  'passings': [3, 7, 2,7,9]
}
myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#      cars  passings
# 0     BMW         3
# 1   Volvo         7
# 2    Ford         2
# 3  Maruti         7
# 4    TATA         9

# %%
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    390
# day2    380
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
myvar = pd.Series(calories, index = ["day1", "day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(myvar.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
print(myvar.loc[[0,1]])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
print(df.loc["day2"])
# Out:
# calories    380
# duration     40
# Name: day2, dtype: int64

# %% [raw]
# # Can Read files and JSON in this

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,"1":60,"2":60,"3":45,"4":45,"5":60
  },
  "Pulse":{
    "0":110,"1":117,"2":103,"3":109,"4":117,"5":102
  },
  "Maxpulse":{
    "0":130,"1":145,"2":135,"3":175,"4":148,"5":127
  },
  "Calories":{
    "0":409.1,"1":479.0,"2":340.0,"3":282.4,"4":406.0,"5":300.5
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5

# %% [raw]
# # CLEANING
#
# dropna() method returns a new DataFrame, and will not change the original.
# fillna() method allows us to replace empty cells with a value

# %%
#Calculate the MEAN, and replace any empty values with it:

import pandas as pd

df = pd.read_csv('data.csv')

x = df["Calories"].mean()

df["Calories"].fillna(x, inplace = True)
# or use : x = df["Calories"].median()
# or use : x = df["Calories"].mode()[0]

# %%
import pandas as pd

df = pd.read_csv('data.csv')
cr = df.corr()

print(cr)
cr.plot()
plt.show()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# ## Plotting

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
df.plot()
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Duration', y = 'Calories')
plt.show()
